# %% [markdown]
# #Clone the Repository

# %%
# !wget https://github.com/skuma17/DNN-and-RNN-based-Speaker-Profiling.git

# %% [markdown]
# ## Install the Pre-requisites

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
cd /content/drive/MyDrive/SpeakerProfiling-main/speaker_nlp
# Out:
# /content/drive/MyDrive/SpeakerProfiling-main/speaker_nlp

# %%
# !pip install --user -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: speechbrain in /root/.local/lib/python3.7/site-packages (from -r requirements.txt (line 1)) (0.5.10)
# Requirement already satisfied: wavencoder in /root/.local/lib/python3.7/site-packages (from -r requirements.txt (line 2)) (0.1.3)
# Requirement already satisfied: torch>=1.7 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 3)) (1.12.1+cu113)
# Requirement already satisfied: torchaudio>=0.7.2 in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 4)) (0.12.1+cu113)
# Requirement already satisfied: pytorch-lightning>=1.1.5 in /root/.local/lib/python3.7/site-packages (from -r requirements.txt (line 5)) (1.7.2)
# Requirement already satisfied: sklearn in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 6)) (0.0)
# Requirement already satisfied: torch-optimizer in /root/.local/lib/python3.7/site-packages (from -r requirements.txt (line 7)) (0.3.0)
# Requirement already satisfied: torchmetrics in /root/.local/lib/python3.7/site-packages (from -r requirements.txt (line 8)) (0.9.3)
# Requirement already satisfied: wandb in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 9)) (0.13.1)
# Requirement already satisfied: tensorboardX in /usr/local/lib/python3.7/dist-packages (from -r requirements.txt (line 10)) (2.5.1)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.7->-r requirements.txt (line 3)) (4.1.1)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in /root/.local/lib/python3.7/site-packages (from pytorch-lightning>=1.1.5->-r requirements.txt (line 5)) (2022.7.1)
# Requirement already satisfied: tensorboard>=2.9.1 in /root/.local/lib/python3.7/site-packages (from pytorch-lightning>=1.1.5->-r requirements.txt (line 5)) (2.10.0)
# Requirement already satisfied: packaging>=17.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.1.5->-r requirements.txt (line 5)) (21.3)
# Requirement already satisfied: tqdm>=4.57.0 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.1.5->-r requirements.txt (line 5)) (4.64.0)
# Requirement already satisfied: PyYAML>=5.4 in /root/.local/lib/python3.7/site-packages (from pytorch-lightning>=1.1.5->-r requirements.txt (line 5)) (6.0)
# Requirement already satisfied: numpy>=1.17.2 in /usr/local/lib/python3.7/dist-packages (from pytorch-lightning>=1.1.5->-r requirements.txt (line 5)) (1.21.6)
# Requirement already satisfied: pyDeprecate>=0.3.1 in /root/.local/lib/python3.7/site-packages (from pytorch-lightning>=1.1.5->-r requirements.txt (line 5)) (0.3.2)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.1.5->-r requirements.txt (line 5)) (3.8.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.1.5->-r requirements.txt (line 5)) (2.23.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from packaging>=17.0->pytorch-lightning>=1.1.5->-r requirements.txt (line 5)) (3.0.9)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning>=1.1.5->-r requirements.txt (line 5)) (1.35.0)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning>=1.1.5->-r requirements.txt (line 5)) (0.6.1)
# Requirement already satisfied: werkzeug>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning>=1.1.5->-r requirements.txt (line 5)) (1.0.1)
# Requirement already satisfied: absl-py>=0.4 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning>=1.1.5->-r requirements.txt (line 5)) (1.2.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning>=1.1.5->-r requirements.txt (line 5)) (0.4.6)
# Requirement already satisfied: setuptools>=41.0.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning>=1.1.5->-r requirements.txt (line 5)) (57.4.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning>=1.1.5->-r requirements.txt (line 5)) (3.4.1)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning>=1.1.5->-r requirements.txt (line 5)) (3.17.3)
# Requirement already satisfied: grpcio>=1.24.3 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning>=1.1.5->-r requirements.txt (line 5)) (1.47.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning>=1.1.5->-r requirements.txt (line 5)) (0.37.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorboard>=2.9.1->pytorch-lightning>=1.1.5->-r requirements.txt (line 5)) (1.8.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning>=1.1.5->-r requirements.txt (line 5)) (4.9)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning>=1.1.5->-r requirements.txt (line 5)) (0.2.8)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning>=1.1.5->-r requirements.txt (line 5)) (1.15.0)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning>=1.1.5->-r requirements.txt (line 5)) (4.2.4)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.7/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->pytorch-lightning>=1.1.5->-r requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard>=2.9.1->pytorch-lightning>=1.1.5->-r requirements.txt (line 5)) (4.12.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard>=2.9.1->pytorch-lightning>=1.1.5->-r requirements.txt (line 5)) (3.8.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /usr/local/lib/python3.7/dist-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->pytorch-lightning>=1.1.5->-r requirements.txt (line 5)) (0.4.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.1.5->-r requirements.txt (line 5)) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.1.5->-r requirements.txt (line 5)) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.1.5->-r requirements.txt (line 5)) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.1.5->-r requirements.txt (line 5)) (2022.6.15)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.7/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.9.1->pytorch-lightning>=1.1.5->-r requirements.txt (line 5)) (3.2.0)
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (from speechbrain->-r requirements.txt (line 1)) (1.7.3)
# Requirement already satisfied: sentencepiece in /usr/local/lib/python3.7/dist-packages (from speechbrain->-r requirements.txt (line 1)) (0.1.97)
# Requirement already satisfied: joblib in /usr/local/lib/python3.7/dist-packages (from speechbrain->-r requirements.txt (line 1)) (1.1.0)
# Requirement already satisfied: huggingface-hub in /usr/local/lib/python3.7/dist-packages (from speechbrain->-r requirements.txt (line 1)) (0.8.1)
# Requirement already satisfied: hyperpyyaml in /usr/local/lib/python3.7/dist-packages (from speechbrain->-r requirements.txt (line 1)) (1.0.1)
# Requirement already satisfied: fairseq in /root/.local/lib/python3.7/site-packages (from wavencoder->-r requirements.txt (line 2)) (0.12.2)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.7/dist-packages (from sklearn->-r requirements.txt (line 6)) (1.0.2)
# Requirement already satisfied: pytorch-ranger>=0.1.1 in /root/.local/lib/python3.7/site-packages (from torch-optimizer->-r requirements.txt (line 7)) (0.1.1)
# Requirement already satisfied: GitPython>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb->-r requirements.txt (line 9)) (3.1.27)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb->-r requirements.txt (line 9)) (5.4.8)
# Requirement already satisfied: shortuuid>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from wandb->-r requirements.txt (line 9)) (1.0.9)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.7/dist-packages (from wandb->-r requirements.txt (line 9)) (1.3.2)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from wandb->-r requirements.txt (line 9)) (0.4.0)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb->-r requirements.txt (line 9)) (1.9.0)
# Requirement already satisfied: pathtools in /usr/local/lib/python3.7/dist-packages (from wandb->-r requirements.txt (line 9)) (0.1.2)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb->-r requirements.txt (line 9)) (7.1.2)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb->-r requirements.txt (line 9)) (2.3)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb->-r requirements.txt (line 9)) (4.0.9)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from gitdb<5,>=4.0.1->GitPython>=1.0.0->wandb->-r requirements.txt (line 9)) (5.0.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.1.5->-r requirements.txt (line 5)) (1.3.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.1.5->-r requirements.txt (line 5)) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.1.5->-r requirements.txt (line 5)) (4.0.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.1.5->-r requirements.txt (line 5)) (2.1.0)
# Requirement already satisfied: asynctest==0.13.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.1.5->-r requirements.txt (line 5)) (0.13.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.1.5->-r requirements.txt (line 5)) (22.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.1.5->-r requirements.txt (line 5)) (1.8.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.7/dist-packages (from aiohttp->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning>=1.1.5->-r requirements.txt (line 5)) (1.2.0)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from fairseq->wavencoder->-r requirements.txt (line 2)) (2022.6.2)
# Requirement already satisfied: hydra-core<1.1,>=1.0.7 in /root/.local/lib/python3.7/site-packages (from fairseq->wavencoder->-r requirements.txt (line 2)) (1.0.7)
# Requirement already satisfied: bitarray in /root/.local/lib/python3.7/site-packages (from fairseq->wavencoder->-r requirements.txt (line 2)) (2.6.0)
# Requirement already satisfied: omegaconf<2.1 in /root/.local/lib/python3.7/site-packages (from fairseq->wavencoder->-r requirements.txt (line 2)) (2.0.6)
# Requirement already satisfied: sacrebleu>=1.4.12 in /root/.local/lib/python3.7/site-packages (from fairseq->wavencoder->-r requirements.txt (line 2)) (2.2.0)
# Requirement already satisfied: cffi in /usr/local/lib/python3.7/dist-packages (from fairseq->wavencoder->-r requirements.txt (line 2)) (1.15.1)
# Requirement already satisfied: cython in /usr/local/lib/python3.7/dist-packages (from fairseq->wavencoder->-r requirements.txt (line 2)) (0.29.32)
# Requirement already satisfied: importlib-resources in /usr/local/lib/python3.7/dist-packages (from hydra-core<1.1,>=1.0.7->fairseq->wavencoder->-r requirements.txt (line 2)) (5.9.0)
# Requirement already satisfied: antlr4-python3-runtime==4.8 in /root/.local/lib/python3.7/site-packages (from hydra-core<1.1,>=1.0.7->fairseq->wavencoder->-r requirements.txt (line 2)) (4.8)
# Requirement already satisfied: portalocker in /root/.local/lib/python3.7/site-packages (from sacrebleu>=1.4.12->fairseq->wavencoder->-r requirements.txt (line 2)) (2.5.1)
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu>=1.4.12->fairseq->wavencoder->-r requirements.txt (line 2)) (0.8.10)
# Requirement already satisfied: colorama in /root/.local/lib/python3.7/site-packages (from sacrebleu>=1.4.12->fairseq->wavencoder->-r requirements.txt (line 2)) (0.4.5)
# Requirement already satisfied: lxml in /usr/local/lib/python3.7/dist-packages (from sacrebleu>=1.4.12->fairseq->wavencoder->-r requirements.txt (line 2)) (4.9.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.7/dist-packages (from cffi->fairseq->wavencoder->-r requirements.txt (line 2)) (2.21)
# Requirement already satisfied: filelock in /usr/local/lib/python3.7/dist-packages (from huggingface-hub->speechbrain->-r requirements.txt (line 1)) (3.8.0)
# Requirement already satisfied: ruamel.yaml>=0.17.8 in /usr/local/lib/python3.7/dist-packages (from hyperpyyaml->speechbrain->-r requirements.txt (line 1)) (0.17.21)
# Requirement already satisfied: ruamel.yaml.clib>=0.2.6 in /usr/local/lib/python3.7/dist-packages (from ruamel.yaml>=0.17.8->hyperpyyaml->speechbrain->-r requirements.txt (line 1)) (0.2.6)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn->sklearn->-r requirements.txt (line 6)) (3.1.0)

# %% [markdown]
# # Dataset

# %% [markdown]
# ## Download the NISP Dataset

# %%
# !wget https://github.com/iiscleap/NISP-Dataset.git

# %% [markdown]
# # Download Noise Dataset

# %%
mkdir noise_dataset

# %%
import wavencoder
wavencoder.utils.download_noise_dataset('noise_dataset', sample_rate='16k', download_all=True)

# %% [markdown]
# # Prepare NISP Dataset

# %%
# !python prepare_nisp_data.py

# %% [markdown]
# Edit config.py with data path or add as arguments

# %% [markdown]
# # Train, Validate and Test the Dataset

# %%
# !python train_nisp.py --data_path="../NISP-Dataset/trim_final_data_16k" --speaker_csv_path="../NISP-Dataset/total_spkrinfo.list" --noise_dataset_path="../noise_dataset" --n_workers=4
# Out:
# 2022-08-19 21:15:10 | INFO | numexpr.utils | NumExpr defaulting to 4 threads.
# 2022-08-19 21:15:11 | INFO | torch.distributed.nn.jit.instantiator | Created a temporary directory at /tmp/tmp9p8pdam6
# 2022-08-19 21:15:11 | INFO | torch.distributed.nn.jit.instantiator | Writing /tmp/tmp9p8pdam6/_remote_module_non_scriptable.py
# Training Model on NISP Dataset
# #Cores = 4	#GPU = 1
# Dataset Split (Train, Validation, Test)= 1766 862 1603
# wandb: Currently logged in as: satishkumar. Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.13.1
# wandb: Run data is saved locally in /content/drive/MyDrive/SpeakerProfiling-main/speaker_nlp/wandb/run-20220819_211514-15dmkf99
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run fresh-disco-579
# wandb: ⭐️ View project at https://wandb.ai/satishkumar/SpeakerProfiling
# wandb: 🚀 View run at https://wandb.ai/satishkumar/SpeakerProfiling/runs/15dmkf99
# Model Details: #Params = 6142215	#Trainable Params = 889095
# 2022-08-19 21:15:16 | INFO | pytorch_lightning.utilities.rank_zero | GPU available: True (cuda), used: True
# 2022-08-19 21:15:16 | INFO | pytorch_lightning.utilities.rank_zero | TPU available: False, using: 0 TPU cores
# 2022-08-19 21:15:16 | INFO | pytorch_lightning.utilities.rank_zero | IPU available: False, using: 0 IPUs
# 2022-08-19 21:15:16 | INFO | pytorch_lightning.utilities.rank_zero | HPU available: False, using: 0 HPUs
# wandb: logging graph, to disable use `wandb.watch(log_graph=False)`
# 2022-08-19 21:15:16 | INFO | pytorch_lightning.utilities.distributed | Initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# 2022-08-19 21:15:16 | INFO | torch.distributed.distributed_c10d | Added key: store_based_barrier_key:1 to store for rank: 0
# 2022-08-19 21:15:16 | INFO | torch.distributed.distributed_c10d | Rank 0: Completed store-based barrier for key:store_based_barrier_key:1 with 1 nodes.
# 2022-08-19 21:15:16 | INFO | pytorch_lightning.utilities.rank_zero | ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 1 processes
# ----------------------------------------------------------------------------------------------------
#
# 2022-08-19 21:15:18 | INFO | pytorch_lightning.accelerators.cuda | LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# 2022-08-19 21:15:19 | INFO | pytorch_lightning.callbacks.model_summary |
#   | Name                     | Type              | Params
# ---------------------------------------------------------------
# 0 | model                    | Wav2VecLSTM_Base  | 6.1 M
# 1 | classification_criterion | MeanSquaredError  | 0
# 2 | regression_criterion     | MeanSquaredError  | 0
# 3 | mae_criterion            | MeanAbsoluteError | 0
# 4 | rmse_criterion           | RMSELoss          | 0
# 5 | accuracy                 | Accuracy          | 0
# ---------------------------------------------------------------
# 889 K     Trainable params
# 5.3 M     Non-trainable params
# 6.1 M     Total params
# 24.569    Total estimated model params size (MB)
# /root/.local/lib/python3.7/site-packages/pytorch_lightning/trainer/trainer.py:1898: PossibleUserWarning: The number of training batches (14) is smaller than the logging interval Trainer(log_every_n_steps=50). Set a lower value for log_every_n_steps if you want to see logs for the training epoch.
#   category=PossibleUserWarning,
# Epoch 0:   0% 0/21 [00:00<?, ?it/s] [W reducer.cpp:1251] Warning: find_unused_parameters=True was specified in DDP constructor, but did not find any unused parameters in the forward pass. This flag results in an extra traversal of the autograd graph every iteration,  which can adversely affect performance. If your model indeed never has any unused parameters in the forward pass, consider turning this flag off. Note that this warning may be a false positive if your model has flow control causing later iterations to have unused parameters. (function operator())
#
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Epoch 0:  95% 20/21 [00:32<00:01,  1.64s/it]
# Epoch 0: 100% 21/21 [00:33<00:00,  1.58s/it, loss=2.43, v_num=kf99, v_loss=2.600, v_nl_acc=0.235, v_a_mae=4.170, v_a_rmse=4.440, v_g_acc=0.725]
#                                                           2022-08-19 21:15:57 | INFO | pytorch_lightning.callbacks.early_stopping | Metric v_loss improved. New best score: 2.603
# Epoch 0: 100% 21/21 [00:33<00:00,  1.58s/it, loss=2.43, v_num=kf99, v_loss=2.600, v_nl_acc=0.235, v_a_mae=4.170, v_a_rmse=4.440, v_g_acc=0.725, epoch_loss=2.430, nl_acc=0.196, a_mae=3.280, a_rmse=4.490, g_acc=0.794]2022-08-19 21:15:57 | INFO | pytorch_lightning.utilities.rank_zero | Epoch 0, global step 14: 'v_loss' reached 2.60310 (best 2.60310), saving model to '/content/drive/MyDrive/SpeakerProfiling-main/speaker_nlp/SpeakerProfiling/15dmkf99/checkpoints/epoch=0-step=14.ckpt' as top 1
# Epoch 1:   0% 0/21 [00:00<?, ?it/s, loss=2.43, v_num=kf99, v_loss=2.600, v_nl_acc=0.235, v_a_mae=4.170, v_a_rmse=4.440, v_g_acc=0.725, epoch_loss=2.430, nl_acc=0.196, a_mae=3.280, a_rmse=4.490, g_acc=0.794]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Epoch 1:  95% 20/21 [00:32<00:01,  1.64s/it, loss=2.43, v_num=kf99, v_loss=2.600, v_nl_acc=0.235, v_a_mae=4.170, v_a_rmse=4.440, v_g_acc=0.725, epoch_loss=2.430, nl_acc=0.196, a_mae=3.280, a_rmse=4.490, g_acc=0.794]
# Epoch 1: 100% 21/21 [00:33<00:00,  1.58s/it, loss=2.37, v_num=kf99, v_loss=2.610, v_nl_acc=0.171, v_a_mae=4.090, v_a_rmse=4.370, v_g_acc=0.725, epoch_loss=2.430, nl_acc=0.196, a_mae=3.280, a_rmse=4.490, g_acc=0.794]
# Epoch 1: 100% 21/21 [00:33<00:00,  1.58s/it, loss=2.37, v_num=kf99, v_loss=2.610, v_nl_acc=0.171, v_a_mae=4.090, v_a_rmse=4.370, v_g_acc=0.725, epoch_loss=2.370, nl_acc=0.178, a_mae=3.220, a_rmse=4.420, g_acc=0.794]2022-08-19 21:16:31 | INFO | pytorch_lightning.utilities.rank_zero | Epoch 1, global step 28: 'v_loss' was not in top 1
# Epoch 2:   0% 0/21 [00:00<?, ?it/s, loss=2.37, v_num=kf99, v_loss=2.610, v_nl_acc=0.171, v_a_mae=4.090, v_a_rmse=4.370, v_g_acc=0.725, epoch_loss=2.370, nl_acc=0.178, a_mae=3.220, a_rmse=4.420, g_acc=0.794]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Epoch 2:  95% 20/21 [00:35<00:01,  1.75s/it, loss=2.37, v_num=kf99, v_loss=2.610, v_nl_acc=0.171, v_a_mae=4.090, v_a_rmse=4.370, v_g_acc=0.725, epoch_loss=2.370, nl_acc=0.178, a_mae=3.220, a_rmse=4.420, g_acc=0.794]
# Epoch 2: 100% 21/21 [00:35<00:00,  1.69s/it, loss=2.35, v_num=kf99, v_loss=2.590, v_nl_acc=0.179, v_a_mae=4.050, v_a_rmse=4.330, v_g_acc=0.725, epoch_loss=2.370, nl_acc=0.178, a_mae=3.220, a_rmse=4.420, g_acc=0.794]
#                                                           2022-08-19 21:17:06 | INFO | pytorch_lightning.callbacks.early_stopping | Metric v_loss improved by 0.016 >= min_delta = 0.0. New best score: 2.587
# Epoch 2: 100% 21/21 [00:35<00:00,  1.69s/it, loss=2.35, v_num=kf99, v_loss=2.590, v_nl_acc=0.179, v_a_mae=4.050, v_a_rmse=4.330, v_g_acc=0.725, epoch_loss=2.330, nl_acc=0.224, a_mae=3.250, a_rmse=4.360, g_acc=0.795]2022-08-19 21:17:06 | INFO | pytorch_lightning.utilities.rank_zero | Epoch 2, global step 42: 'v_loss' reached 2.58682 (best 2.58682), saving model to '/content/drive/MyDrive/SpeakerProfiling-main/speaker_nlp/SpeakerProfiling/15dmkf99/checkpoints/epoch=2-step=42.ckpt' as top 1
# Epoch 3:   0% 0/21 [00:00<?, ?it/s, loss=2.35, v_num=kf99, v_loss=2.590, v_nl_acc=0.179, v_a_mae=4.050, v_a_rmse=4.330, v_g_acc=0.725, epoch_loss=2.330, nl_acc=0.224, a_mae=3.250, a_rmse=4.360, g_acc=0.795]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Epoch 3:  95% 20/21 [00:35<00:01,  1.75s/it, loss=2.35, v_num=kf99, v_loss=2.590, v_nl_acc=0.179, v_a_mae=4.050, v_a_rmse=4.330, v_g_acc=0.725, epoch_loss=2.330, nl_acc=0.224, a_mae=3.250, a_rmse=4.360, g_acc=0.795]
# Epoch 3: 100% 21/21 [00:35<00:00,  1.69s/it, loss=2.3, v_num=kf99, v_loss=2.510, v_nl_acc=0.146, v_a_mae=4.090, v_a_rmse=4.380, v_g_acc=0.725, epoch_loss=2.330, nl_acc=0.224, a_mae=3.250, a_rmse=4.360, g_acc=0.795]
#                                                           2022-08-19 21:17:42 | INFO | pytorch_lightning.callbacks.early_stopping | Metric v_loss improved by 0.078 >= min_delta = 0.0. New best score: 2.509
# Epoch 3: 100% 21/21 [00:35<00:00,  1.69s/it, loss=2.3, v_num=kf99, v_loss=2.510, v_nl_acc=0.146, v_a_mae=4.090, v_a_rmse=4.380, v_g_acc=0.725, epoch_loss=2.270, nl_acc=0.250, a_mae=3.090, a_rmse=4.230, g_acc=0.795]2022-08-19 21:17:42 | INFO | pytorch_lightning.utilities.rank_zero | Epoch 3, global step 56: 'v_loss' reached 2.50922 (best 2.50922), saving model to '/content/drive/MyDrive/SpeakerProfiling-main/speaker_nlp/SpeakerProfiling/15dmkf99/checkpoints/epoch=3-step=56.ckpt' as top 1
# Epoch 4:   0% 0/21 [00:00<?, ?it/s, loss=2.3, v_num=kf99, v_loss=2.510, v_nl_acc=0.146, v_a_mae=4.090, v_a_rmse=4.380, v_g_acc=0.725, epoch_loss=2.270, nl_acc=0.250, a_mae=3.090, a_rmse=4.230, g_acc=0.795]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Epoch 4:  95% 20/21 [00:33<00:01,  1.65s/it, loss=2.3, v_num=kf99, v_loss=2.510, v_nl_acc=0.146, v_a_mae=4.090, v_a_rmse=4.380, v_g_acc=0.725, epoch_loss=2.270, nl_acc=0.250, a_mae=3.090, a_rmse=4.230, g_acc=0.795]
# Epoch 4: 100% 21/21 [00:33<00:00,  1.59s/it, loss=2.12, v_num=kf99, v_loss=2.440, v_nl_acc=0.0882, v_a_mae=4.110, v_a_rmse=4.540, v_g_acc=0.725, epoch_loss=2.270, nl_acc=0.250, a_mae=3.090, a_rmse=4.230, g_acc=0.795]
#                                                           2022-08-19 21:18:16 | INFO | pytorch_lightning.callbacks.early_stopping | Metric v_loss improved by 0.067 >= min_delta = 0.0. New best score: 2.443
# Epoch 4: 100% 21/21 [00:33<00:00,  1.59s/it, loss=2.12, v_num=kf99, v_loss=2.440, v_nl_acc=0.0882, v_a_mae=4.110, v_a_rmse=4.540, v_g_acc=0.725, epoch_loss=2.100, nl_acc=0.337, a_mae=2.930, a_rmse=3.910, g_acc=0.795]2022-08-19 21:18:16 | INFO | pytorch_lightning.utilities.rank_zero | Epoch 4, global step 70: 'v_loss' reached 2.44268 (best 2.44268), saving model to '/content/drive/MyDrive/SpeakerProfiling-main/speaker_nlp/SpeakerProfiling/15dmkf99/checkpoints/epoch=4-step=70.ckpt' as top 1
# Epoch 5:   0% 0/21 [00:00<?, ?it/s, loss=2.12, v_num=kf99, v_loss=2.440, v_nl_acc=0.0882, v_a_mae=4.110, v_a_rmse=4.540, v_g_acc=0.725, epoch_loss=2.100, nl_acc=0.337, a_mae=2.930, a_rmse=3.910, g_acc=0.795]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Epoch 5:  95% 20/21 [00:31<00:01,  1.60s/it, loss=2.12, v_num=kf99, v_loss=2.440, v_nl_acc=0.0882, v_a_mae=4.110, v_a_rmse=4.540, v_g_acc=0.725, epoch_loss=2.100, nl_acc=0.337, a_mae=2.930, a_rmse=3.910, g_acc=0.795]
# Epoch 5: 100% 21/21 [00:32<00:00,  1.54s/it, loss=1.99, v_num=kf99, v_loss=2.540, v_nl_acc=0.110, v_a_mae=3.940, v_a_rmse=4.370, v_g_acc=0.992, epoch_loss=2.100, nl_acc=0.337, a_mae=2.930, a_rmse=3.910, g_acc=0.795]
# Epoch 5: 100% 21/21 [00:32<00:00,  1.54s/it, loss=1.99, v_num=kf99, v_loss=2.540, v_nl_acc=0.110, v_a_mae=3.940, v_a_rmse=4.370, v_g_acc=0.992, epoch_loss=1.970, nl_acc=0.376, a_mae=2.830, a_rmse=3.730, g_acc=0.873]2022-08-19 21:18:49 | INFO | pytorch_lightning.utilities.rank_zero | Epoch 5, global step 84: 'v_loss' was not in top 1
# Epoch 6:   0% 0/21 [00:00<?, ?it/s, loss=1.99, v_num=kf99, v_loss=2.540, v_nl_acc=0.110, v_a_mae=3.940, v_a_rmse=4.370, v_g_acc=0.992, epoch_loss=1.970, nl_acc=0.376, a_mae=2.830, a_rmse=3.730, g_acc=0.873]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Epoch 6:  95% 20/21 [00:32<00:01,  1.61s/it, loss=1.99, v_num=kf99, v_loss=2.540, v_nl_acc=0.110, v_a_mae=3.940, v_a_rmse=4.370, v_g_acc=0.992, epoch_loss=1.970, nl_acc=0.376, a_mae=2.830, a_rmse=3.730, g_acc=0.873]
# Epoch 6: 100% 21/21 [00:32<00:00,  1.56s/it, loss=1.87, v_num=kf99, v_loss=2.680, v_nl_acc=0.112, v_a_mae=3.680, v_a_rmse=4.050, v_g_acc=0.993, epoch_loss=1.970, nl_acc=0.376, a_mae=2.830, a_rmse=3.730, g_acc=0.873]
# Epoch 6: 100% 21/21 [00:32<00:00,  1.56s/it, loss=1.87, v_num=kf99, v_loss=2.680, v_nl_acc=0.112, v_a_mae=3.680, v_a_rmse=4.050, v_g_acc=0.993, epoch_loss=1.820, nl_acc=0.408, a_mae=2.540, a_rmse=3.490, g_acc=0.962]2022-08-19 21:19:22 | INFO | pytorch_lightning.utilities.rank_zero | Epoch 6, global step 98: 'v_loss' was not in top 1
# Epoch 7:   0% 0/21 [00:00<?, ?it/s, loss=1.87, v_num=kf99, v_loss=2.680, v_nl_acc=0.112, v_a_mae=3.680, v_a_rmse=4.050, v_g_acc=0.993, epoch_loss=1.820, nl_acc=0.408, a_mae=2.540, a_rmse=3.490, g_acc=0.962]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Epoch 7:  95% 20/21 [00:33<00:01,  1.66s/it, loss=1.87, v_num=kf99, v_loss=2.680, v_nl_acc=0.112, v_a_mae=3.680, v_a_rmse=4.050, v_g_acc=0.993, epoch_loss=1.820, nl_acc=0.408, a_mae=2.540, a_rmse=3.490, g_acc=0.962]
# Epoch 7: 100% 21/21 [00:33<00:00,  1.60s/it, loss=1.68, v_num=kf99, v_loss=2.920, v_nl_acc=0.0692, v_a_mae=3.740, v_a_rmse=4.140, v_g_acc=1.000, epoch_loss=1.820, nl_acc=0.408, a_mae=2.540, a_rmse=3.490, g_acc=0.962]
# Epoch 7: 100% 21/21 [00:33<00:00,  1.60s/it, loss=1.68, v_num=kf99, v_loss=2.920, v_nl_acc=0.0692, v_a_mae=3.740, v_a_rmse=4.140, v_g_acc=1.000, epoch_loss=1.650, nl_acc=0.423, a_mae=2.300, a_rmse=3.200, g_acc=0.975]2022-08-19 21:19:56 | INFO | pytorch_lightning.utilities.rank_zero | Epoch 7, global step 112: 'v_loss' was not in top 1
# Epoch 8:   0% 0/21 [00:00<?, ?it/s, loss=1.68, v_num=kf99, v_loss=2.920, v_nl_acc=0.0692, v_a_mae=3.740, v_a_rmse=4.140, v_g_acc=1.000, epoch_loss=1.650, nl_acc=0.423, a_mae=2.300, a_rmse=3.200, g_acc=0.975]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Epoch 8:  95% 20/21 [00:31<00:01,  1.58s/it, loss=1.68, v_num=kf99, v_loss=2.920, v_nl_acc=0.0692, v_a_mae=3.740, v_a_rmse=4.140, v_g_acc=1.000, epoch_loss=1.650, nl_acc=0.423, a_mae=2.300, a_rmse=3.200, g_acc=0.975]
# Epoch 8: 100% 21/21 [00:31<00:00,  1.52s/it, loss=1.51, v_num=kf99, v_loss=3.410, v_nl_acc=0.0681, v_a_mae=4.030, v_a_rmse=4.630, v_g_acc=0.998, epoch_loss=1.650, nl_acc=0.423, a_mae=2.300, a_rmse=3.200, g_acc=0.975]
# Epoch 8: 100% 21/21 [00:31<00:00,  1.52s/it, loss=1.51, v_num=kf99, v_loss=3.410, v_nl_acc=0.0681, v_a_mae=4.030, v_a_rmse=4.630, v_g_acc=0.998, epoch_loss=1.490, nl_acc=0.455, a_mae=2.160, a_rmse=2.970, g_acc=0.989]2022-08-19 21:20:28 | INFO | pytorch_lightning.utilities.rank_zero | Epoch 8, global step 126: 'v_loss' was not in top 1
# Epoch 9:   0% 0/21 [00:00<?, ?it/s, loss=1.51, v_num=kf99, v_loss=3.410, v_nl_acc=0.0681, v_a_mae=4.030, v_a_rmse=4.630, v_g_acc=0.998, epoch_loss=1.490, nl_acc=0.455, a_mae=2.160, a_rmse=2.970, g_acc=0.989]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Epoch 9:  95% 20/21 [00:32<00:01,  1.63s/it, loss=1.51, v_num=kf99, v_loss=3.410, v_nl_acc=0.0681, v_a_mae=4.030, v_a_rmse=4.630, v_g_acc=0.998, epoch_loss=1.490, nl_acc=0.455, a_mae=2.160, a_rmse=2.970, g_acc=0.989]
# Epoch 9: 100% 21/21 [00:33<00:00,  1.57s/it, loss=1.42, v_num=kf99, v_loss=3.060, v_nl_acc=0.148, v_a_mae=3.630, v_a_rmse=4.060, v_g_acc=0.999, epoch_loss=1.490, nl_acc=0.455, a_mae=2.160, a_rmse=2.970, g_acc=0.989]
# Epoch 9: 100% 21/21 [00:33<00:00,  1.58s/it, loss=1.42, v_num=kf99, v_loss=3.060, v_nl_acc=0.148, v_a_mae=3.630, v_a_rmse=4.060, v_g_acc=0.999, epoch_loss=1.410, nl_acc=0.460, a_mae=2.000, a_rmse=2.770, g_acc=0.992]2022-08-19 21:21:01 | INFO | pytorch_lightning.utilities.rank_zero | Epoch 9, global step 140: 'v_loss' was not in top 1
# Epoch 10:   0% 0/21 [00:00<?, ?it/s, loss=1.42, v_num=kf99, v_loss=3.060, v_nl_acc=0.148, v_a_mae=3.630, v_a_rmse=4.060, v_g_acc=0.999, epoch_loss=1.410, nl_acc=0.460, a_mae=2.000, a_rmse=2.770, g_acc=0.992]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Epoch 10:  95% 20/21 [00:31<00:01,  1.57s/it, loss=1.42, v_num=kf99, v_loss=3.060, v_nl_acc=0.148, v_a_mae=3.630, v_a_rmse=4.060, v_g_acc=0.999, epoch_loss=1.410, nl_acc=0.460, a_mae=2.000, a_rmse=2.770, g_acc=0.992]
# Epoch 10: 100% 21/21 [00:31<00:00,  1.52s/it, loss=1.4, v_num=kf99, v_loss=3.390, v_nl_acc=0.158, v_a_mae=3.760, v_a_rmse=4.380, v_g_acc=1.000, epoch_loss=1.410, nl_acc=0.460, a_mae=2.000, a_rmse=2.770, g_acc=0.992]
# Epoch 10: 100% 21/21 [00:31<00:00,  1.52s/it, loss=1.4, v_num=kf99, v_loss=3.390, v_nl_acc=0.158, v_a_mae=3.760, v_a_rmse=4.380, v_g_acc=1.000, epoch_loss=1.360, nl_acc=0.484, a_mae=2.100, a_rmse=2.960, g_acc=0.987]2022-08-19 21:21:33 | INFO | pytorch_lightning.utilities.rank_zero | Epoch 10, global step 154: 'v_loss' was not in top 1
# Epoch 11:   0% 0/21 [00:00<?, ?it/s, loss=1.4, v_num=kf99, v_loss=3.390, v_nl_acc=0.158, v_a_mae=3.760, v_a_rmse=4.380, v_g_acc=1.000, epoch_loss=1.360, nl_acc=0.484, a_mae=2.100, a_rmse=2.960, g_acc=0.987]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Epoch 11:  95% 20/21 [00:32<00:01,  1.60s/it, loss=1.4, v_num=kf99, v_loss=3.390, v_nl_acc=0.158, v_a_mae=3.760, v_a_rmse=4.380, v_g_acc=1.000, epoch_loss=1.360, nl_acc=0.484, a_mae=2.100, a_rmse=2.960, g_acc=0.987]
# Epoch 11: 100% 21/21 [00:32<00:00,  1.55s/it, loss=1.24, v_num=kf99, v_loss=3.400, v_nl_acc=0.225, v_a_mae=4.240, v_a_rmse=4.880, v_g_acc=1.000, epoch_loss=1.360, nl_acc=0.484, a_mae=2.100, a_rmse=2.960, g_acc=0.987]
# Epoch 11: 100% 21/21 [00:32<00:00,  1.55s/it, loss=1.24, v_num=kf99, v_loss=3.400, v_nl_acc=0.225, v_a_mae=4.240, v_a_rmse=4.880, v_g_acc=1.000, epoch_loss=1.220, nl_acc=0.541, a_mae=1.920, a_rmse=2.670, g_acc=0.995]2022-08-19 21:22:05 | INFO | pytorch_lightning.utilities.rank_zero | Epoch 11, global step 168: 'v_loss' was not in top 1
# Epoch 12:   0% 0/21 [00:00<?, ?it/s, loss=1.24, v_num=kf99, v_loss=3.400, v_nl_acc=0.225, v_a_mae=4.240, v_a_rmse=4.880, v_g_acc=1.000, epoch_loss=1.220, nl_acc=0.541, a_mae=1.920, a_rmse=2.670, g_acc=0.995]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Epoch 12:  95% 20/21 [00:31<00:01,  1.60s/it, loss=1.24, v_num=kf99, v_loss=3.400, v_nl_acc=0.225, v_a_mae=4.240, v_a_rmse=4.880, v_g_acc=1.000, epoch_loss=1.220, nl_acc=0.541, a_mae=1.920, a_rmse=2.670, g_acc=0.995]
# Epoch 12: 100% 21/21 [00:32<00:00,  1.54s/it, loss=1.36, v_num=kf99, v_loss=2.950, v_nl_acc=0.104, v_a_mae=3.890, v_a_rmse=4.260, v_g_acc=0.997, epoch_loss=1.220, nl_acc=0.541, a_mae=1.920, a_rmse=2.670, g_acc=0.995]
# Epoch 12: 100% 21/21 [00:32<00:00,  1.54s/it, loss=1.36, v_num=kf99, v_loss=2.950, v_nl_acc=0.104, v_a_mae=3.890, v_a_rmse=4.260, v_g_acc=0.997, epoch_loss=1.430, nl_acc=0.512, a_mae=2.060, a_rmse=3.020, g_acc=0.979]2022-08-19 21:22:38 | INFO | pytorch_lightning.utilities.rank_zero | Epoch 12, global step 182: 'v_loss' was not in top 1
# Epoch 13:   0% 0/21 [00:00<?, ?it/s, loss=1.36, v_num=kf99, v_loss=2.950, v_nl_acc=0.104, v_a_mae=3.890, v_a_rmse=4.260, v_g_acc=0.997, epoch_loss=1.430, nl_acc=0.512, a_mae=2.060, a_rmse=3.020, g_acc=0.979]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Epoch 13:  95% 20/21 [00:32<00:01,  1.62s/it, loss=1.36, v_num=kf99, v_loss=2.950, v_nl_acc=0.104, v_a_mae=3.890, v_a_rmse=4.260, v_g_acc=0.997, epoch_loss=1.430, nl_acc=0.512, a_mae=2.060, a_rmse=3.020, g_acc=0.979]
# Epoch 13: 100% 21/21 [00:32<00:00,  1.56s/it, loss=1.42, v_num=kf99, v_loss=2.750, v_nl_acc=0.356, v_a_mae=3.600, v_a_rmse=4.160, v_g_acc=1.000, epoch_loss=1.430, nl_acc=0.512, a_mae=2.060, a_rmse=3.020, g_acc=0.979]
# Epoch 13: 100% 21/21 [00:32<00:00,  1.57s/it, loss=1.42, v_num=kf99, v_loss=2.750, v_nl_acc=0.356, v_a_mae=3.600, v_a_rmse=4.160, v_g_acc=1.000, epoch_loss=1.390, nl_acc=0.528, a_mae=2.360, a_rmse=3.070, g_acc=0.967]2022-08-19 21:23:10 | INFO | pytorch_lightning.utilities.rank_zero | Epoch 13, global step 196: 'v_loss' was not in top 1
# Epoch 14:   0% 0/21 [00:00<?, ?it/s, loss=1.42, v_num=kf99, v_loss=2.750, v_nl_acc=0.356, v_a_mae=3.600, v_a_rmse=4.160, v_g_acc=1.000, epoch_loss=1.390, nl_acc=0.528, a_mae=2.360, a_rmse=3.070, g_acc=0.967]
# Validation: 0it [00:00, ?it/s]
# Validation:   0% 0/7 [00:00<?, ?it/s]
# Epoch 14:  95% 20/21 [00:32<00:01,  1.61s/it, loss=1.42, v_num=kf99, v_loss=2.750, v_nl_acc=0.356, v_a_mae=3.600, v_a_rmse=4.160, v_g_acc=1.000, epoch_loss=1.390, nl_acc=0.528, a_mae=2.360, a_rmse=3.070, g_acc=0.967]
# Epoch 14: 100% 21/21 [00:32<00:00,  1.55s/it, loss=1.2, v_num=kf99, v_loss=3.440, v_nl_acc=0.185, v_a_mae=4.300, v_a_rmse=4.860, v_g_acc=0.994, epoch_loss=1.390, nl_acc=0.528, a_mae=2.360, a_rmse=3.070, g_acc=0.967]
#                                                           2022-08-19 21:23:43 | INFO | pytorch_lightning.callbacks.early_stopping | Monitored metric v_loss did not improve in the last 10 records. Best score: 2.443. Signaling Trainer to stop.
# Epoch 14: 100% 21/21 [00:32<00:00,  1.55s/it, loss=1.2, v_num=kf99, v_loss=3.440, v_nl_acc=0.185, v_a_mae=4.300, v_a_rmse=4.860, v_g_acc=0.994, epoch_loss=1.160, nl_acc=0.618, a_mae=1.930, a_rmse=2.750, g_acc=0.992]2022-08-19 21:23:43 | INFO | pytorch_lightning.utilities.rank_zero | Epoch 14, global step 210: 'v_loss' was not in top 1
# Epoch 14: 100% 21/21 [00:32<00:00,  1.55s/it, loss=1.2, v_num=kf99, v_loss=3.440, v_nl_acc=0.185, v_a_mae=4.300, v_a_rmse=4.860, v_g_acc=0.994, epoch_loss=1.160, nl_acc=0.618, a_mae=1.930, a_rmse=2.750, g_acc=0.992]
#
#  Completed Training...
# Testing the model with checkpoint
#   /content/drive/MyDrive/SpeakerProfiling-main/speaker_nlp/SpeakerProfiling/15dmkf99/checkpoints/epoch=4-step=70.ckpt
# Model Details: #Params = 6142215	#Trainable Params = 889095
#
# Testing on NISP Dataset:
#
# 2022-08-19 21:23:44 | INFO | pytorch_lightning.accelerators.cuda | LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# Testing DataLoader 0: 100% 13/13 [00:06<00:00,  2.06it/s]/root/.local/lib/python3.7/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:540: PossibleUserWarning: It is recommended to use `self.log('test_native_languages_acc', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
#   category=PossibleUserWarning,
# /root/.local/lib/python3.7/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:540: PossibleUserWarning: It is recommended to use `self.log('male_age_mae', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
#   category=PossibleUserWarning,
# /root/.local/lib/python3.7/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:540: PossibleUserWarning: It is recommended to use `self.log('female_age_mae', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
#   category=PossibleUserWarning,
# /root/.local/lib/python3.7/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:540: PossibleUserWarning: It is recommended to use `self.log('male_age_rmse', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
#   category=PossibleUserWarning,
# /root/.local/lib/python3.7/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:540: PossibleUserWarning: It is recommended to use `self.log('female_age_rmse', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
#   category=PossibleUserWarning,
# /root/.local/lib/python3.7/site-packages/pytorch_lightning/trainer/connectors/logger_connector/result.py:540: PossibleUserWarning: It is recommended to use `self.log('test_gender_acc', ..., sync_dist=True)` when logging on epoch level in distributed setting to accumulate the metric across devices.
#   category=PossibleUserWarning,
# Testing DataLoader 0: 100% 13/13 [00:06<00:00,  2.06it/s]
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#        Test metric             DataLoader 0
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
#      female_age_mae                 nan
#      female_age_rmse                nan
#       male_age_mae           5.419961929321289
#       male_age_rmse          6.35401725769043
#      test_gender_acc        0.8004807829856873
# test_native_languages_acc   0.19457699358463287
# ────────────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# wandb: Waiting for W&B process to finish... (success).
# wandb:
# wandb:
# wandb: Run history:
# wandb:                     a_mae ███▇▆▆▄▃▂▁▂▁▂▃▁
# wandb:                    a_rmse ██▇▇▆▅▄▃▂▁▂▁▂▃▁
# wandb:                     epoch ▁▁▁▁▂▂▂▂▂▃▃▃▃▄▄▄▄▄▅▅▅▅▆▆▆▆▆▇▇▇▇████
# wandb:                epoch_loss ██▇▇▆▅▅▄▃▂▂▁▂▂▁
# wandb:                     g_acc ▁▁▁▁▁▄▇▇████▇▇█
# wandb:              male_age_mae ▁
# wandb:             male_age_rmse ▁
# wandb:                    nl_acc ▁▁▂▂▄▄▅▅▅▅▆▇▆▇█
# wandb:           test_gender_acc ▁
# wandb: test_native_languages_acc ▁
# wandb:          train_loss_epoch ██▇▇▆▅▅▄▃▂▂▁▂▂▁
# wandb:           train_loss_step █▆▁▁
# wandb:       trainer/global_step ▁▁▁▁▂▂▂▂▂▃▃▃▃▄▄▄▄▄▅▅▅▅▆▆▆▆▆▇▇▇▇████
# wandb:                   v_a_mae ▇▆▆▆▆▄▂▂▅▁▃▇▄▁█
# wandb:                  v_a_rmse ▄▄▃▄▅▄▁▂▆▁▄█▃▂█
# wandb:                   v_g_acc ▁▁▁▁▁██████████
# wandb:                    v_loss ▂▂▂▁▁▂▃▄█▅██▅▃█
# wandb:                  v_nl_acc ▅▄▄▃▁▂▂▁▁▃▃▅▂█▄
# wandb:
# wandb: Run summary:
# wandb:                     a_mae 1.93226
# wandb:                    a_rmse 2.74835
# wandb:                     epoch 15
# wandb:                epoch_loss 1.16207
# wandb:            female_age_mae nan
# wandb:           female_age_rmse nan
# wandb:                     g_acc 0.99205
# wandb:              male_age_mae 5.41996
# wandb:             male_age_rmse 6.35402
# wandb:                    nl_acc 0.61776
# wandb:           test_gender_acc 0.80048
# wandb: test_native_languages_acc 0.19458
# wandb:          train_loss_epoch 1.16339
# wandb:           train_loss_step 1.34026
# wandb:       trainer/global_step 210
# wandb:                   v_a_mae 4.30315
# wandb:                  v_a_rmse 4.85933
# wandb:                   v_g_acc 0.99442
# wandb:                    v_loss 3.43728
# wandb:                  v_nl_acc 0.18475
# wandb:
# wandb: Synced fresh-disco-579: https://wandb.ai/satishkumar/SpeakerProfiling/runs/15dmkf99
# wandb: Synced 5 W&B file(s), 1 media file(s), 4 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20220819_211514-15dmkf99/logs
